# %% [markdown]
# Unemployment, total (% of total labor force) (modeled ILO estimate)

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '/Users/saketmanolkar/Desktop/india/unemploymentdata.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
df.head()
# Out:
#                   Country Name 1960 1961 1962 1963 1964 1965 1966 1967 1968  \
# 0                        Aruba   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 1  Africa Eastern and Southern   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 2                  Afghanistan   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 3   Africa Western and Central   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 4                       Angola   NA   NA   NA   NA   NA   NA   NA   NA   NA
#
#    ...      2013      2014      2015      2016      2017      2018      2019  \
# 0  ...        NA        NA        NA        NA        NA        NA        NA
# 1  ...  6.512784  6.555646  6.707142  6.855589  6.940365  6.913046  7.121663
# 2  ...     7.949      7.91     8.989    10.086     11.18     11.11    11.085
# 3  ...  3.804447  3.985878  4.241136  4.112958  4.140484  4.201599  4.261414
# 4  ...     8.834      9.58     9.584     9.586     9.535     9.522     9.481
#
#        2020      2021      2022
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']

# Drop rows with missing values
df_india = df_india.dropna()

# Extract the years and GDP values without specifying column names
years = df_india.columns[1:].values.astype(int)
gdp_values = df_india.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for India
plt.plot(years, gdp_values, label='India', marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %  (% of total labor force)')
plt.title('Unemployment (% of total labor force) Over Time - India')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df_india
# Out:
#     Country Name 1960 1961 1962 1963 1964 1965 1966 1967 1968  ...   2013  \
# 109        India   NA   NA   NA   NA   NA   NA   NA   NA   NA  ...  8.037
#
#       2014   2015   2016   2017  2018  2019    2020   2021  2022
# 109  7.981  7.915  7.842  7.733  7.65  6.51  10.195  7.713  7.33
#
# [1 rows x 64 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for the United States
df_us = df[df['Country Name'] == 'United States']

# Drop rows with missing values
df_us = df_us.dropna()

# Extract the years and unemployment values without specifying column names
years_us = df_us.columns[1:].values.astype(int)
unemployment_values_us = df_us.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for the United States
plt.plot(years_us, unemployment_values_us, label='United States', marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Over the Years: United States')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df_us
# Out:
#       Country Name 1960 1961 1962 1963 1964 1965 1966 1967 1968  ...  2013  \
# 251  United States   NA   NA   NA   NA   NA   NA   NA   NA   NA  ...  7.37
#
#      2014  2015  2016  2017 2018  2019  2020  2021   2022
# 251  6.17  5.28  4.87  4.36  3.9  3.67  8.05  5.35  3.611
#
# [1 rows x 64 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for the United States
df_us = df[df['Country Name'] == 'United States']
df_us = df_us.dropna()
years_us = df_us.columns[1:].values.astype(int)
unemployment_us = df_us.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Select data for Pakistan
#df_pakistan = df[df['Country Name'] == 'Pakistan']
#df_pakistan = df_pakistan.dropna()
#years_pakistan = df_pakistan.columns[1:].values.astype(int)
#unemployment_pakistan = df_pakistan.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for the United States
plt.plot(years_us, unemployment_us, label='United States', marker='o', linestyle='-')

# Plot a line graph for India
plt.plot(years_india, unemployment_india, label='India', marker='o', linestyle='-')

# Plot a line graph for Pakistan
#plt.plot(years_pakistan, unemployment_pakistan, label='Pakistan', marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment (% of total labor force) Over Time - India and United States')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for the United States
df_us = df[df['Country Name'] == 'China']
df_us = df_us.dropna()
years_us = df_us.columns[1:].values.astype(int)
unemployment_us = df_us.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Select data for Pakistan
#df_pakistan = df[df['Country Name'] == 'Pakistan']
#df_pakistan = df_pakistan.dropna()
#years_pakistan = df_pakistan.columns[1:].values.astype(int)
#unemployment_pakistan = df_pakistan.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for the United States
plt.plot(years_us, unemployment_us, label='China', marker='o', linestyle='-')

# Plot a line graph for India
plt.plot(years_india, unemployment_india, label='India', marker='o', linestyle='-')

# Plot a line graph for Pakistan
#plt.plot(years_pakistan, unemployment_pakistan, label='Pakistan', marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment (% of total labor force) Over Time - India and China')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for first-world countries
first_world_countries = ['India','United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']

# Filter data for the selected first-world countries
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for first-world countries
for country in first_world_countries:
    df_country = df[df['Country Name'] == country]
    df_country = df_country.dropna()
    unemployment_country = df_country.iloc[0, 1:].replace('NA', np.nan).astype(float).values
    plt.plot(years_first_world, unemployment_country, label=country, marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment (% of total labor force)')
plt.title('Unemployment (% of total labor force) Over Time - India and First World Countries')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for first-world countries
first_world_countries = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan']

# Filter data for the selected first-world countries
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[0, 1:].replace('NA', np.nan).astype(float).values

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for first-world countries
for country in first_world_countries:
    df_country = df[df['Country Name'] == country]
    df_country = df_country.dropna()
    unemployment_country = df_country.iloc[0, 1:].replace('NA', np.nan).astype(float).values
    plt.plot(years_first_world, unemployment_country, label=country, marker='o', linestyle='-')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Over the Years - Indian Subcontinent')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2023, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland',
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania',
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# List of regions and their corresponding country lists
regions = {
    'Africa': africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Function to calculate the average unemployment rate for a list of countries
def calculate_avg_unemployment(countries, df):
    data = df[df['Country Name'].isin(countries)].iloc[:, 2:].apply(pd.to_numeric, errors='coerce').fillna(df.iloc[:, 2:].mean(numeric_only=True))
    avg_unemployment = data.mean(axis=0)
    return avg_unemployment

# Plotting
plt.figure(figsize=(12, 8))

for region, countries in regions.items():
    avg_unemployment = calculate_avg_unemployment(countries, df)
    
    # Convert the index to integers before filtering
    avg_unemployment_filtered = avg_unemployment[avg_unemployment.index.astype(int) > 1989]
    
    plt.plot(avg_unemployment_filtered.index, avg_unemployment_filtered, label=region, marker='o')

plt.xlabel('Year')
plt.ylabel('Average Unemployment %')
plt.title('Average Unemployment Over Time for Different Regions')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.xticks(avg_unemployment_filtered.index[::5])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# List of regions and their corresponding country lists
regions = {
    
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    
}

# Function to calculate the average unemployment rate for a list of countries
def calculate_avg_unemployment(countries, df):
    data = df[df['Country Name'].isin(countries)].iloc[:, 2:].apply(pd.to_numeric, errors='coerce').fillna(df.iloc[:, 2:].mean(numeric_only=True))
    avg_unemployment = data.mean(axis=0)
    return avg_unemployment

# Plotting
plt.figure(figsize=(12, 8))

for region, countries in regions.items():
    avg_unemployment = calculate_avg_unemployment(countries, df)
    
    # Convert the index to integers before filtering
    avg_unemployment_filtered = avg_unemployment[avg_unemployment.index.astype(int) > 1989]
    
    plt.plot(avg_unemployment_filtered.index, avg_unemployment_filtered, label=region, marker='o')

plt.xlabel('Year')
plt.ylabel('Average Unemployment %')
plt.title('Average Unemployment Over Time for Different Regions')
plt.legend()
plt.grid(True)
plt.xticks(avg_unemployment_filtered.index[::5])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].replace('NA', np.nan).astype(float).values

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[:, 1:].replace('NA', np.nan).astype(float).values

# Calculate the average unemployment rate for each year across first-world countries
avg_unemployment_first_world = np.mean(unemployment_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot a line graph for India
plt.plot(years_india, unemployment_india.flatten(), label='India', marker='o', linestyle='-')

# Plot a line graph for the average unemployment rate of first-world countries
plt.plot(years_first_world, avg_unemployment_first_world, label='Average Unemployment (First World)', color='r', linestyle='--')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Comparison: India vs. First World Countries')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2025, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
unemployment_india_training = unemployment_india[mask_training]

# Calculate the average unemployment rate for each year across first-world countries
avg_unemployment_first_world = np.mean(unemployment_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, unemployment_india, label='Actual Unemployment (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_unemployment_first_world, label='Actual Avg. Unemployment (First World)', color='r', linestyle='--')

# ARIMA order selection using auto_arima or other methods

# ARIMA for India
model_india = ARIMA(unemployment_india_training, order=(0, 1, 2))
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_unemployment_india = fit_india.forecast(steps=len(future_years_india))

# ARIMA for the average of first-world countries
model_first_world = ARIMA(avg_unemployment_first_world, order=(5, 1, 1))
fit_first_world = model_first_world.fit()
predicted_unemployment_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values only
print("Predicted Unemployment (India):", predicted_unemployment_india)
print("Predicted Unemployment (First World):", predicted_unemployment_first_world)

# Plot predicted values for India
plt.plot(future_years_india, predicted_unemployment_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years_india, predicted_unemployment_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Comparison: India vs. First World Countries (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted Unemployment (India): [8.64637359 8.23066584 8.23066584 8.23066584 8.23066584 8.23066584
#  8.23066584 8.23066584 8.23066584 8.23066584 8.23066584 8.23066584
#  8.23066584 8.23066584 8.23066584 8.23066584 8.23066584 8.23066584
#  8.23066584 8.23066584 8.23066584 8.23066584 8.23066584 8.23066584
#  8.23066584 8.23066584 8.23066584 8.23066584]
# Predicted Unemployment (First World): [4.3979114  4.84189675 4.76787306 4.59857011 4.62431492 4.68950876
#  4.68062119 4.65546196 4.65847244 4.66817383 4.667174   4.6634361
#  4.66375998 4.66519917 4.6650979  4.66454414 4.66457415 4.66478708
#  4.66477897 4.66469715 4.66469895 4.66473037 4.66473018 4.66471813
#  4.66471801 4.66472263 4.66472275 4.66472098]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
unemployment_india_training = unemployment_india[mask_training]

# Calculate the average unemployment rate for each year across first-world countries
avg_unemployment_first_world = np.mean(unemployment_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, unemployment_india, label='Actual Unemployment (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_unemployment_first_world, label='Actual Avg. Unemployment (First World)', color='r', linestyle='--')

# ARIMA order selection using auto_arima or other methods

# ARIMA for India with different order
model_india = ARIMA(unemployment_india_training, order=(0, 0, 0))
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_unemployment_india = fit_india.forecast(steps=len(future_years_india))

# ARIMA for the average of first-world countries with different order
model_first_world = ARIMA(avg_unemployment_first_world, order=(2, 1, 0))
fit_first_world = model_first_world.fit()
predicted_unemployment_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values only
print("Predicted Unemployment (India):", predicted_unemployment_india)
print("Predicted Unemployment (First World):", predicted_unemployment_first_world)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(unemployment_india[-len(future_years_india):], predicted_unemployment_india)
mse_india = mean_squared_error(unemployment_india[-len(future_years_india):], predicted_unemployment_india)

mae_first_world = mean_absolute_error(avg_unemployment_first_world[-len(future_years_india):], predicted_unemployment_first_world)
mse_first_world = mean_squared_error(avg_unemployment_first_world[-len(future_years_india):], predicted_unemployment_first_world)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

print("MAE (First World):", mae_first_world)
print("MSE (First World):", mse_first_world)

# Plot predicted values for India
plt.plot(future_years_india, predicted_unemployment_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years_india, predicted_unemployment_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Comparison: India vs. First World'.format(mae_india, mse_india, mae_first_world, mse_first_world))
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted Unemployment (India): [7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262]
# Predicted Unemployment (First World): [4.40757162 4.83153311 4.76892955 4.61077901 4.62345098 4.68176442
#  4.68087762 4.65961778 4.65858369 4.66624796 4.66711301 4.66438141
#  4.66389258 4.66485462 4.66509375 4.6647592  4.6646509  4.66476564
#  4.66481233 4.6647736  4.66475414 4.66476699 4.66477488 4.66477071
#  4.66476758 4.66476889 4.66477012 4.66476972]
# MAE (India): 0.4902443853286832
# MSE (India): 0.4632199781098746
# MAE (First World): 1.7955017939255988
# MSE (First World): 4.054970860661598

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
unemployment_india_training = unemployment_india[mask_training]

# Calculate the average unemployment rate for each year across first-world countries
avg_unemployment_first_world = np.mean(unemployment_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, unemployment_india, label='Actual Unemployment (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_unemployment_first_world, label='Actual Avg. Unemployment (First World)', color='r', linestyle='--')

# ARIMA order selection using auto_arima or other methods

# ARIMA for India with different order
model_india = ARIMA(unemployment_india_training, order=(0, 0, 0))
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_unemployment_india = fit_india.forecast(steps=len(future_years_india))

# ARIMA for the average of first-world countries with different order
model_first_world = ARIMA(avg_unemployment_first_world, order=(2, 1, 0))
fit_first_world = model_first_world.fit()
predicted_unemployment_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values only
print("Predicted Unemployment (India):", predicted_unemployment_india)
print("Predicted Unemployment (First World):", predicted_unemployment_first_world)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(unemployment_india[-len(future_years_india):], predicted_unemployment_india)
mse_india = mean_squared_error(unemployment_india[-len(future_years_india):], predicted_unemployment_india)

mae_first_world = mean_absolute_error(avg_unemployment_first_world[-len(future_years_india):], predicted_unemployment_first_world)
mse_first_world = mean_squared_error(avg_unemployment_first_world[-len(future_years_india):], predicted_unemployment_first_world)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

print("MAE (First World):", mae_first_world)
print("MSE (First World):", mse_first_world)

# Plot predicted values for India
plt.plot(future_years_india, predicted_unemployment_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years_india, predicted_unemployment_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Comparison: India vs. First World Countries (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout
# Out:
# Predicted Unemployment (India): [7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262
#  7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262 7.8330262]
# Predicted Unemployment (First World): [4.40757162 4.83153311 4.76892955 4.61077901 4.62345098 4.68176442
#  4.68087762 4.65961778 4.65858369 4.66624796 4.66711301 4.66438141
#  4.66389258 4.66485462 4.66509375 4.6647592  4.6646509  4.66476564
#  4.66481233 4.6647736  4.66475414 4.66476699 4.66477488 4.66477071
#  4.66476758 4.66476889 4.66477012 4.66476972]
# MAE (India): 0.4902443853286832
# MSE (India): 0.4632199781098746
# MAE (First World): 1.7955017939255988
# MSE (First World): 4.054970860661598
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].replace('NA', np.nan).astype(float).values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and unemployment values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
unemployment_first_world = df_first_world.iloc[:, 1:].replace('NA', np.nan).astype(float).values

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training_india = (years_india >= start_year_training) & (years_india <= end_year_training)
mask_training_first_world = (years_first_world >= start_year_training) & (years_first_world <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training_india]
unemployment_india_training = unemployment_india[mask_training_india]

years_first_world_training = years_first_world[mask_training_first_world]
unemployment_first_world_training = unemployment_first_world[:, mask_training_first_world]

# Impute missing values for Linear Regression
imputer = SimpleImputer(strategy='mean')
train_unemployment_india_imputed = imputer.fit_transform(unemployment_india_training.reshape(-1, 1))
train_unemployment_first_world_imputed = imputer.fit_transform(unemployment_first_world_training.T)

# Linear Regression for India
model_linear_india = LinearRegression().fit(years_india_training.reshape(-1, 1), train_unemployment_india_imputed)
predicted_unemployment_linear_india = model_linear_india.predict(np.arange(2023, 2051).reshape(-1, 1)).flatten()

# Linear Regression for the average of first-world countries
avg_unemployment_first_world_imputed = np.mean(train_unemployment_first_world_imputed, axis=1)
model_linear_first_world = LinearRegression().fit(years_first_world_training.reshape(-1, 1), avg_unemployment_first_world_imputed)
predicted_unemployment_linear_first_world = model_linear_first_world.predict(np.arange(2023, 2051).reshape(-1, 1)).flatten()

# Plot actual values for India
plt.plot(years_india_training, unemployment_india_training, label='Actual Unemployment (India)', marker='o', linestyle='-', color='blue')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world_training, np.mean(unemployment_first_world_training, axis=0), label='Actual Avg. Unemployment (First World)', color='red', linestyle='-')

# Plot predicted values for Linear Regression (India)
plt.plot(np.arange(2023, 2051), predicted_unemployment_linear_india, label='Linear Regression Prediction (India)', linestyle='--', color='green')

# Plot predicted values for Linear Regression (First World)
plt.plot(np.arange(2023, 2051), predicted_unemployment_linear_first_world, label='Linear Regression Prediction (First World)', linestyle='--', color='purple')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Prediction: Linear Regression (India) vs. First World Countries')
plt.legend()

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and unemployment values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
unemployment_india = df_india.iloc[:, 1:].replace('NA', np.nan).astype(float).values.flatten()

# Split data into training and testing sets
train_size = int(len(years_india) * 0.8)
train_years, test_years = years_india[:train_size], years_india[train_size:]
train_unemployment, test_unemployment = unemployment_india[:train_size], unemployment_india[train_size:]

# Handle NaN values for ARIMA
valid_data_arima = ~np.isnan(train_unemployment)
train_years_arima, train_unemployment_arima = train_years[valid_data_arima], train_unemployment[valid_data_arima]
model_arima = ARIMA(train_unemployment_arima, order=(5, 1, 1))
fit_arima = model_arima.fit()

# Handle NaN values for Linear Regression
valid_data_linear = ~np.isnan(train_unemployment)
train_years_linear, train_unemployment_linear = train_years[valid_data_linear], train_unemployment[valid_data_linear]
model_linear = LinearRegression().fit(train_years_linear.reshape(-1, 1), train_unemployment_linear)

# Predict using ARIMA for the entire time period (1960 to 2050)
future_years = np.arange(2023, 2051, 1)
predicted_unemployment_arima = fit_arima.forecast(steps=len(future_years))

# Predict using Linear Regression for the entire time period (1960 to 2050)
predicted_unemployment_linear = model_linear.predict(future_years.reshape(-1, 1))

# Plot actual values for India
plt.plot(years_india, unemployment_india, label='Actual Unemployment (India)', marker='o', linestyle='-')

# Plot predicted values for ARIMA
plt.plot(future_years, predicted_unemployment_arima, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for Linear Regression
plt.plot(future_years, predicted_unemployment_linear, label='Linear Regression Prediction (India)', linestyle='--', color='green')

# Calculate metrics for ARIMA
mae_arima = mean_absolute_error(unemployment_india[-len(future_years):], predicted_unemployment_arima)
mse_arima = mean_squared_error(unemployment_india[-len(future_years):], predicted_unemployment_arima)
rmse_arima = np.sqrt(mse_arima)
mape_arima = np.mean(np.abs((unemployment_india[-len(future_years):] - predicted_unemployment_arima) / unemployment_india[-len(future_years):])) * 100

# Calculate metrics for Linear Regression
mae_linear = mean_absolute_error(unemployment_india[-len(future_years):], predicted_unemployment_linear)
mse_linear = mean_squared_error(unemployment_india[-len(future_years):], predicted_unemployment_linear)
rmse_linear = np.sqrt(mse_linear)
mape_linear = np.mean(np.abs((unemployment_india[-len(future_years):] - predicted_unemployment_linear) / unemployment_india[-len(future_years):])) * 100

# Print metrics
print("\nARIMA Metrics:")
print("MAE: {:.4f}".format(mae_arima))
print("MSE: {:.4f}".format(mse_arima))
print("RMSE: {:.4f}".format(rmse_arima))
print("MAPE: {:.4f}%".format(mape_arima))

print("\nLinear Regression Metrics:")
print("MAE: {:.4f}".format(mae_linear))
print("MSE: {:.4f}".format(mse_linear))
print("RMSE: {:.4f}".format(rmse_linear))
print("MAPE: {:.4f}%".format(mape_linear))

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate Prediction Comparison: ARIMA vs. Linear Regression (India)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ARIMA Metrics:
# MAE: 0.5566
# MSE: 0.5470
# RMSE: 0.7396
# MAPE: 7.2173%
#
# Linear Regression Metrics:
# MAE: 4.1586
# MSE: 18.4803
# RMSE: 4.2989
# MAPE: 53.0026%
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
