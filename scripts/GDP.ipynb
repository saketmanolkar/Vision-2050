# %%
import pandas as pd

import matplotlib.pyplot as plt
# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '//Users/saketmanolkar/Desktop/india/GDPdata.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
df
# Out:
#                     Country Name           1960           1961           1962  \
# 0                          Aruba             NA             NA             NA
# 1    Africa Eastern and Southern  21125015452.0  21616228139.0  23506279900.0
# 2                    Afghanistan    537777811.1    548888895.6    546666677.8
# 3     Africa Western and Central  10447637853.0  11173212080.0  11990534018.0
# 4                         Angola             NA             NA             NA
# ..                           ...            ...            ...            ...
# 261                       Kosovo             NA             NA             NA
# 262                  Yemen, Rep.             NA             NA             NA
# 263                 South Africa   8748596504.0   9225996313.0   9813996078.0
# 264                       Zambia    713000000.0    696285714.3    693142857.1
# 265                     Zimbabwe   1052990400.0   1096646600.0   1117601600.0
#
# ...

# %%
# Assuming 'Country Name' is the name of the column
print(df[df['Country Name'] == 'Algeria'])
# Out:
#    Country Name          1960          1961          1962          1963  \
# 60      Algeria  2723615449.0  2434747054.0  2001444542.0  2702982015.0
#
#             1964          1965          1966          1967          1968  ...  \
# 60  2909316433.0  3136284304.0  3039859185.0  3370870374.0  3852147024.0  ...
#
#               2013            2014            2015            2016  \
# 60  209755003251.0  213809980721.0  165979224317.0  160034212613.0
#
#               2017            2018            2019            2020  \
# 60  170096989043.0  174910891124.0  171760290068.0  145743722826.0
#
#               2021            2022
# 60  163472233246.0  191912889421.0
#
# [1 rows x 64 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# Set the "Country Name" column as the index
df.set_index("Country Name", inplace=True)

# Select the row corresponding to India
india_data = df.loc["India", "1960":"2022"]

# Plot the data with rotated x-axis labels and every 5th label
plt.figure(figsize=(12, 6))
plt.plot(india_data.index, india_data.values, marker='o', linestyle='-', color='b')
plt.title('GDP Over the Years - India')
plt.xlabel('Year')
plt.ylabel('GDP (in trillions)')
plt.xticks(india_data.index[::5], rotation=45, ha="right")  # Plot every 5th label
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace 'Country Name' with the actual column name containing country names
# and assuming the years are in columns from '1960' to '2022'
india_data = df.loc[df['Country Name'] == 'India', '1960':'2022']
pakistan_data = df.loc[df['Country Name'] == 'Pakistan', '1960':'2022']

# Plot the data for India
plt.figure(figsize=(12, 6))
plt.plot(india_data.columns.astype(int), india_data.values.flatten(), marker='o', linestyle='-', color='b', label='India')

# Plot the data for Pakistan
plt.plot(pakistan_data.columns.astype(int), pakistan_data.values.flatten(), marker='o', linestyle='-', color='g', label='Pakistan')

plt.title('GDP Over the Years - India and Pakistan')
plt.xlabel('Year')
plt.ylabel('GDP (in trillions)')
plt.xticks(india_data.columns.astype(int)[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace 'Country Name' with the actual column name containing country names
# and assuming the years are in columns from '1960' to '2022'
india_data = df.loc[df['Country Name'] == 'India', '1960':'2022']
pakistan_data = df.loc[df['Country Name'] == 'China', '1960':'2022']

# Plot the data for India
plt.figure(figsize=(12, 6))
plt.plot(india_data.columns.astype(int), india_data.values.flatten(), marker='o', linestyle='-', color='b', label='India')

# Plot the data for Pakistan
plt.plot(pakistan_data.columns.astype(int), pakistan_data.values.flatten(), marker='o', linestyle='-', color='g', label='China')

plt.title('GDP Over the Years - India and China')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.xticks(india_data.columns.astype(int)[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland'
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Function to calculate the average GDP for a list of countries
def calculate_avg_gdp(countries, df):
    # Fill NaN values with the mean of each column
    data = df[df['Country Name'].isin(countries)].iloc[:, 2:].apply(pd.to_numeric, errors='coerce').fillna(df.iloc[:, 2:].mean())
    avg_gdp = data.mean(axis=0)
    return avg_gdp

# List of continents and their corresponding country lists
continents = {
    'Africa': africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Filter out non-numeric columns
numeric_columns = df.columns[df.columns.str.isnumeric()]

# Convert columns to numeric, ignoring errors
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Extract numeric part of column names
years = df.columns[df.columns.str.isnumeric()].astype(int)

# Plotting
plt.figure(figsize=(12, 8))

for continent, countries in continents.items():
    avg_gdp = calculate_avg_gdp(countries, df)
    # Make sure both years and avg_gdp have the same length
    plt.plot(years[:len(avg_gdp)], avg_gdp, marker='o', label=continent)

plt.title('Average GDP Over Time for Continents and Regions')
plt.xlabel('Year')
plt.ylabel('Average GDP')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Function to calculate the average GDP for a list of countries
def calculate_avg_gdp(countries, df):
    # Fill NaN values with the mean of each column
    data = df[df['Country Name'].isin(countries)].iloc[:, 2:].apply(pd.to_numeric, errors='coerce').fillna(df.iloc[:, 2:].mean())
    avg_gdp = data.mean(axis=0)
    return avg_gdp

# List of continents and their corresponding country lists
continents = {
    
    "Northern Africa": northern_africa_countries,
    "Eastern Europe": eastern_europe,
  
    
    
    
}

# Filter out non-numeric columns
numeric_columns = df.columns[df.columns.str.isnumeric()]

# Convert columns to numeric, ignoring errors
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Extract numeric part of column names
years = df.columns[df.columns.str.isnumeric()].astype(int)

# Plotting
plt.figure(figsize=(12, 8))

for continent, countries in continents.items():
    avg_gdp = calculate_avg_gdp(countries, df)
    # Make sure both years and avg_gdp have the same length
    plt.plot(years[:len(avg_gdp)], avg_gdp, marker='o', label=continent)

plt.title('Average GDP Over Time for Continents and Regions')
plt.xlabel('Year')
plt.ylabel('Average GDP')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# Set the "Country Name" column as the index
df.set_index("Country Name", inplace=True)

# List of subcontinent countries (you can modify this list)
subcontinent_countries = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal']

# Plot the data for subcontinent countries
plt.figure(figsize=(14, 8))

for country in subcontinent_countries:
    country_data = df.loc[country, "1960":"2022"]
    plt.plot(country_data.index, country_data.values, marker='o', linestyle='-', label=country)

plt.title('GDP Over the Years - Indian Subcontinent Countries')
plt.xlabel('Year')
plt.ylabel('GDP (in trillions)')
plt.xticks(df.columns, rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# List of subcontinent countries (you can modify this list)
subcontinent_countries = ['Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal']

# Filter DataFrame for subcontinent countries
subcontinent_data = df[df.index.isin(subcontinent_countries)].loc[:, '1960':'2022']

# Plot the data for subcontinent countries
plt.figure(figsize=(14, 8))

# Plot each country
for country in subcontinent_data.index:
    plt.plot(subcontinent_data.columns.astype(int), subcontinent_data.loc[country].values, marker='o', linestyle='-', label=country)

plt.title('GDP Over the Years - Subcontinent Countries (excluding India)')
plt.xlabel('Year')
plt.ylabel('GDP (in 100 millions)')
plt.xticks(subcontinent_data.columns.astype(int)[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# List of subcontinent countries (you can modify this list)
subcontinent_countries = ['India','United States']

# Filter DataFrame for subcontinent countries
subcontinent_data = df[df.index.isin(subcontinent_countries)].loc[:, '1960':'2022']

# Plot the data for subcontinent countries
plt.figure(figsize=(14, 8))

# Plot each country
for country in subcontinent_data.index:
    plt.plot(subcontinent_data.columns.astype(int), subcontinent_data.loc[country].values, marker='o', linestyle='-', label=country)

plt.title('GDP Over the Years - India and United States')
plt.xlabel('Year')
plt.ylabel('GDP (in 10 trillions)')
plt.xticks(subcontinent_data.columns.astype(int)[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# List of first world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']

# Plot the data for first world countries
plt.figure(figsize=(14, 8))

# Plot each country
for country in first_world_countries:
    country_data = df.loc[country, "1960":"2022"]
    
    # Convert the index to strings
    x_values = country_data.index.astype(str)
    
    # Convert y-axis values to float, handling non-numeric values
    y_values = pd.to_numeric(country_data.values, errors='coerce')
    
    plt.plot(x_values, y_values, marker='o', linestyle='-', label=country)

plt.title('GDP Over the Years - First World Countries')
plt.xlabel('Year')
plt.ylabel('GDP (in 100 millions)')
plt.xticks(rotation=45, ha="right")  # Let matplotlib decide the x-axis ticks
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [45], in <cell line: 14>()
#      13 # Plot each country
#      14 for country in first_world_countries:
# ---> 15     country_data = df.loc[country, "1960":"2022"]
#      17     # Convert the index to strings
#      18     x_values = country_data.index.astype(str)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1140, in _LocIndexer._getitem_tuple(self, tup)
#    1138 with suppress(IndexingError):
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# Set the "Country Name" column as the index
df.set_index("Country Name", inplace=True)

# List of first world countries
first_world_countries = ['United States', 'India', 'United Kingdom', 'Germany', 'France', 'Japan', 'China']

# Plot the data for first world countries
plt.figure(figsize=(14, 8))

for country in first_world_countries:
    country_data = df.loc[country, "1960":"2022"]
    
    # Convert the index to strings
    x_values = country_data.index.astype(str)
    
    # Convert y-axis values to float, handling non-numeric values
    y_values = pd.to_numeric(country_data.values, errors='coerce')
    
    plt.plot(x_values, y_values, marker='o', linestyle='-', label=country)

plt.title('GDP Over the Years - India vs First World Countries')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.xticks(df.columns[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Replace df with your actual DataFrame

# Set the "Country Name" column as the index
df.set_index("Country Name", inplace=True)

# List of first world countries
first_world_countries = ['United States', 'India', 'United Kingdom', 'Germany', 'France', 'Japan', 'China']
# Plot the data for India
india_data = df.loc['India', "1960":"2022"]
x_values_india = india_data.index.astype(str)
y_values_india = pd.to_numeric(india_data.values, errors='coerce')

# Plot the data for the average of first world countries
avg_data = df.loc[first_world_countries, "1960":"2022"].mean()
x_values_avg = avg_data.index.astype(str)
y_values_avg = pd.to_numeric(avg_data.values, errors='coerce')

# Plotting
plt.figure(figsize=(14, 8))

plt.plot(x_values_india, y_values_india, marker='o', linestyle='-', label='India', color='blue')
plt.plot(x_values_avg, y_values_avg, marker='o', linestyle='-', label='Average of First World Countries', color='green')

plt.title('GDP Over the Years - India vs. Average of First World Countries')
plt.xlabel('Year')
plt.ylabel('GDP ')
plt.xticks(df.columns[::5], rotation=45, ha="right")  # Plot every 5th label
plt.legend()
plt.grid(True)
plt.tight_layout()  # Adjust layout for better appearance
plt.show()
# Out:
# /var/folders/h1/6025h_3n69s9h1v7w12_f24c0000gn/T/ipykernel_2251/1034301598.py:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg_data = df.loc[first_world_countries, "1960":"2022"].mean()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and GDP values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
gdp_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and GDP values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
gdp_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Handle missing values by filling with the mean
gdp_india = np.nan_to_num(gdp_india, nan=np.nanmean(gdp_india))
gdp_first_world = np.nan_to_num(gdp_first_world, nan=np.nanmean(gdp_first_world))

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
gdp_india_training = gdp_india[mask_training]

# Calculate the average GDP for each year across first-world countries
avg_gdp_first_world = np.mean(gdp_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_india, label='Actual GDP (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_gdp_first_world, label='Actual Avg. GDP (First World)', color='r', linestyle='--')

# ARIMA order selection (You can experiment with different values)
order_india = (1, 1, 3)
order_first_world = (2, 1, 1)

# ARIMA for India with different order
model_india = ARIMA(gdp_india_training, order=order_india)
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_gdp_india = fit_india.forecast(steps=len(future_years_india))

# ARIMA for the average of first-world countries with different order
model_first_world = ARIMA(avg_gdp_first_world, order=order_first_world)
fit_first_world = model_first_world.fit()
predicted_gdp_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values for India
print("Predicted GDP (India):", predicted_gdp_india)

# Print predicted values for the average of first-world countries
print("Predicted GDP (First World):", predicted_gdp_first_world)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_india[-len(future_years_india):], predicted_gdp_india)
mse_india = mean_squared_error(gdp_india[-len(future_years_india):], predicted_gdp_india)

mae_first_world = mean_absolute_error(avg_gdp_first_world[-len(future_years_india):], predicted_gdp_first_world)
mse_first_world = mean_squared_error(avg_gdp_first_world[-len(future_years_india):], predicted_gdp_first_world)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

print("MAE (First World):", mae_first_world)
print("MSE (First World):", mse_first_world)

# Plot predicted values for India
plt.plot(future_years_india, predicted_gdp_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years_india, predicted_gdp_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Comparison: India vs. First World Countries (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP (India): [3.43995758e+12 3.56466504e+12 3.70979039e+12 3.84920565e+12
#  3.98313547e+12 4.11179569e+12 4.23539365e+12 4.35412852e+12
#  4.46819165e+12 4.57776686e+12 4.68303072e+12 4.78415287e+12
#  4.88129627e+12 4.97461747e+12 5.06426685e+12 5.15038889e+12
#  5.23312237e+12 5.31260062e+12 5.38895173e+12 5.46229872e+12
#  5.53275980e+12 5.60044852e+12 5.66547396e+12 5.72794091e+12
#  5.78795004e+12 5.84559805e+12 5.90097784e+12 5.95417866e+12]
# Predicted GDP (First World): [6.32282215e+12 6.43585337e+12 6.54761966e+12 6.65837237e+12
#  6.76813700e+12 6.87692347e+12 6.98474058e+12 7.09159697e+12
#  7.19750120e+12 7.30246175e+12 7.40648704e+12 7.50958540e+12
#  7.61176508e+12 7.71303428e+12 7.81340111e+12 7.91287360e+12
#  8.01145973e+12 8.10916740e+12 8.20600442e+12 8.30197857e+12
#  8.39709752e+12 8.49136891e+12 8.58480028e+12 8.67739911e+12
#  8.76917283e+12 8.86012878e+12 8.95027426e+12 9.03961649e+12]
# MAE (India): 3424055127704.081
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and GDP values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
gdp_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and GDP values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
gdp_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Handle missing values by filling with the mean
gdp_india = np.nan_to_num(gdp_india, nan=np.nanmean(gdp_india))
gdp_first_world = np.nan_to_num(gdp_first_world, nan=np.nanmean(gdp_first_world))

# Filter data for training on years 1990 to 2022
start_year_training = 1990
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
gdp_india_training = gdp_india[mask_training]

# Calculate the average GDP for each year across first-world countries
avg_gdp_first_world = np.mean(gdp_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_india, label='Actual GDP (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_gdp_first_world, label='Actual Avg. GDP (First World)', color='r', linestyle='--')

# ARIMA order selection (You can experiment with different values)
order_india = (3, 1, 3)
order_first_world = (2, 1, 1)

# ARIMA for India with different order
model_india = ARIMA(gdp_india_training, order=order_india)
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_gdp_india = fit_india.forecast(steps=len(future_years_india))

# ARIMA for the average of first-world countries with different order
model_first_world = ARIMA(avg_gdp_first_world, order=order_first_world)
fit_first_world = model_first_world.fit()
predicted_gdp_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values for India
print("Predicted GDP (India):", predicted_gdp_india)

# Print predicted values for the average of first-world countries
print("Predicted GDP (First World):", predicted_gdp_first_world)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_india[-len(future_years_india):], predicted_gdp_india)
mse_india = mean_squared_error(gdp_india[-len(future_years_india):], predicted_gdp_india)

mae_first_world = mean_absolute_error(avg_gdp_first_world[-len(future_years_india):], predicted_gdp_first_world)
mse_first_world = mean_squared_error(avg_gdp_first_world[-len(future_years_india):], predicted_gdp_first_world)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

print("MAE (First World):", mae_first_world)
print("MSE (First World):", mse_first_world)

# Plot predicted values for India
plt.plot(future_years_india, predicted_gdp_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years_india, predicted_gdp_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Comparison: India vs. First World Countries (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1990, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP (India): [3.65502755e+12 3.69107230e+12 3.85869409e+12 3.99682040e+12
#  4.08333105e+12 4.24940573e+12 4.33834296e+12 4.47106470e+12
#  4.58966577e+12 4.69290010e+12 4.81925430e+12 4.91949321e+12
#  5.03340798e+12 5.14052718e+12 5.24234730e+12 5.35000935e+12
#  5.44814482e+12 5.54978788e+12 5.64780802e+12 5.74330490e+12
#  5.83945906e+12 5.93151436e+12 6.02372921e+12 6.11365833e+12
#  6.20186327e+12 6.28924386e+12 6.37434908e+12 6.45857367e+12]
# Predicted GDP (First World): [6.32282215e+12 6.43585337e+12 6.54761966e+12 6.65837237e+12
#  6.76813700e+12 6.87692347e+12 6.98474058e+12 7.09159697e+12
#  7.19750120e+12 7.30246175e+12 7.40648704e+12 7.50958540e+12
#  7.61176508e+12 7.71303428e+12 7.81340111e+12 7.91287360e+12
#  8.01145973e+12 8.10916740e+12 8.20600442e+12 8.30197857e+12
#  8.39709752e+12 8.49136891e+12 8.58480028e+12 8.67739911e+12
#  8.76917283e+12 8.86012878e+12 8.95027426e+12 9.03961649e+12]
# MAE (India): 3656509257351.2695
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
import warnings

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']
df_india = df_india.dropna()

# Extract years and GDP values without specifying column names
years_india = df_india.columns[1:].values.astype(int)
gdp_india = df_india.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values.flatten()

# Select data for first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia']
df_first_world = df[df['Country Name'].isin(first_world_countries)]
df_first_world = df_first_world.dropna()

# Extract years and GDP values without specifying column names
years_first_world = df_first_world.columns[1:].values.astype(int)
gdp_first_world = df_first_world.iloc[:, 1:].apply(pd.to_numeric, errors='coerce').values

# Handle missing values by filling with the mean
gdp_india = np.nan_to_num(gdp_india, nan=np.nanmean(gdp_india))
gdp_first_world = np.nan_to_num(gdp_first_world, nan=np.nanmean(gdp_first_world))

# Filter data for training on years 1960 to 2022
start_year_training = 1970
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for both India and first-world countries
years_india_training = years_india[mask_training]
gdp_india_training = gdp_india[mask_training]

# Calculate the average GDP for each year across first-world countries
avg_gdp_first_world = np.mean(gdp_first_world, axis=0)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_india, label='Actual GDP (India)', marker='o', linestyle='-')

# Plot actual values for the average of first-world countries
plt.plot(years_first_world, avg_gdp_first_world, label='Actual Avg. GDP (First World)', color='r', linestyle='--')

# ARIMA order selection (You can experiment with different values)
order_india = (10, 1, 10)
order_first_world = (5, 1, 5)

# Fit the ARIMA model for India
model_india = auto_arima(gdp_india_training, trace=True, suppress_warnings=True)
fit_india = model_india.fit(gdp_india_training)

# Fit the ARIMA model for the average of first-world countries
model_first_world = auto_arima(avg_gdp_first_world, trace=True, suppress_warnings=True)
fit_first_world = model_first_world.fit(avg_gdp_first_world)

# Predict GDP for India from 2023 to 2050
future_years = np.arange(2023, 2051)
predicted_gdp_india = fit_india.predict(n_periods=len(future_years))

# Predict GDP for the average of first-world countries from 2023 to 2050
predicted_gdp_first_world = fit_first_world.predict(n_periods=len(future_years))

# Plot predicted values for India
plt.plot(future_years, predicted_gdp_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Plot predicted values for the average of first-world countries
plt.plot(future_years, predicted_gdp_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Comparison: India vs. First World Countries (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(np.arange(min(years_india), max(future_years)+1, 5))

# Show the plot
plt.show()

# Print predicted values and accuracy measures
print("Predicted GDP for India (2023 to 2050):")
print(predicted_gdp_india)

# Calculate accuracy measures for India
mae_india = mean_absolute_error(gdp_india_training, fit_india.predict_in_sample())
mse_india = mean_squared_error(gdp_india_training, fit_india.predict_in_sample())
print(f"MAE (India): {mae_india}")
print(f"MSE (India): {mse_india}")

# Print predicted values and accuracy measures for the average of first-world countries
print("\nPredicted Avg. GDP for First World (2023 to 2050):")
print(predicted_gdp_first_world)

# Calculate accuracy measures for the average of first-world countries
mae_first_world = mean_absolute_error(avg_gdp_first_world, fit_first_world.predict_in_sample())
mse_first_world = mean_squared_error(avg_gdp_first_world, fit_first_world.predict_in_sample())
print(f"MAE (First World): {mae_first_world}")
print(f"MSE (First World): {mse_first_world}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=2733.073, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2764.405, Time=0.00 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=2747.150, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=2732.942, Time=0.01 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=2733.772, Time=0.01 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=2733.617, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=2732.016, Time=0.05 sec
#  ARIMA(1,2,3)(0,0,0)[0]             : AIC=2739.135, Time=0.03 sec
#  ARIMA(0,2,3)(0,0,0)[0]             : AIC=2739.691, Time=0.01 sec
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# ...
