# %%
import pandas as pd

import matplotlib.pyplot as plt
# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '/Users/saketmanolkar/Desktop/india/GDP growth.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
print(df[df['Country Name'] == 'India'])
# Out:
#     Country Name 1960      1961      1962      1963     1964     1965  \
# 109        India   NA  3.722743  2.931128  5.994353  7.45295 -2.63577
#
#          1966      1967      1968  ...      2013      2014      2015  \
# 109 -0.055329  7.825963  3.387929  ...  6.386106  7.410228  7.996254
#
#          2016      2017      2018      2019      2020      2021      2022
# 109  8.256306  6.795383  6.453851  3.871437 -5.831053  9.050278  7.002952
#
# [1 rows x 64 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Extract the row for India
india_data = df[df['Country Name'] == 'India']

# Drop columns with 'NA' values
india_data = india_data.dropna(axis=1)

# Select the column containing GDP data and convert to numeric
india_gdp_data = pd.to_numeric(india_data.iloc[:, 1:].squeeze(), errors='coerce')

# Increase figure size
plt.figure(figsize=(10, 6))

# Plotting
plt.plot(india_gdp_data.index, india_gdp_data.values, marker='o', linestyle='-', color='b')
plt.title('GDP Growth Rate Over Time - India')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')

# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(india_gdp_data.index[::5])  # Skip every 5th entry
plt.grid(True)
plt.tight_layout()  # Adjust layout for better readability
plt.show()

# %%
df['Country Name'] == 'India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# Name: Country Name, Length: 266, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Extract the rows for India and Pakistan
india_data = df[df['Country Name'] == 'India'].dropna()
pakistan_data = df[df['Country Name'] == 'Pakistan'].dropna()

# Convert values to numeric
india_data = india_data.apply(pd.to_numeric, errors='coerce')
pakistan_data = pakistan_data.apply(pd.to_numeric, errors='coerce')

# Increase figure size
plt.figure(figsize=(10, 6))

# Plotting for India
plt.plot(india_data.columns[1:], india_data.iloc[:, 1:].values.squeeze(), marker='o', linestyle='-', color='b', label='India')

# Plotting for Pakistan
plt.plot(pakistan_data.columns[1:], pakistan_data.iloc[:, 1:].values.squeeze(), marker='o', linestyle='-', color='g', label='Pakistan')

plt.title('GDP Growth Rate Over Time - India and Pakistan')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.legend()



# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)

plt.tight_layout()  # Adjust layout for better readability
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Extract the rows for India and Pakistan
india_data = df[df['Country Name'] == 'India'].dropna()
pakistan_data = df[df['Country Name'] == 'China'].dropna()

# Convert values to numeric
india_data = india_data.apply(pd.to_numeric, errors='coerce')
pakistan_data = pakistan_data.apply(pd.to_numeric, errors='coerce')

# Increase figure size
plt.figure(figsize=(10, 6))

# Plotting for India
plt.plot(india_data.columns[1:], india_data.iloc[:, 1:].values.squeeze(), marker='o', linestyle='-', color='b', label='India')

# Plotting for Pakistan
plt.plot(pakistan_data.columns[1:], pakistan_data.iloc[:, 1:].values.squeeze(), marker='o', linestyle='-', color='g', label='China')

plt.title('GDP Growth Rate Over Time - India and China')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.legend()



# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)

plt.tight_layout()  # Adjust layout for better readability
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# List of countries in the Indian subcontinent
indian_subcontinent_countries = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan']

# Increase figure size
plt.figure(figsize=(12, 8))

# Iterate through countries and plot
for country in indian_subcontinent_countries:
    # Extract the data for the current country
    country_data = df[df['Country Name'] == country].dropna(axis=1)

    # Convert values to numeric
    country_data = country_data.apply(pd.to_numeric, errors='coerce')

    # Plotting for the current country
    plt.plot(country_data.columns[1:], country_data.iloc[:, 1:].values.squeeze(), label=country, marker='o', linestyle='-')

plt.title('GDP Growth Rate Over Time - Indian Subcontinent Countries')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')

# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)
plt.tight_layout()

# Show legend
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# List of countries in the Indian subcontinent
indian_subcontinent_countries = ['India', 'United States']

# Increase figure size
plt.figure(figsize=(12, 8))

# Iterate through countries and plot
for country in indian_subcontinent_countries:
    # Extract the data for the current country
    country_data = df[df['Country Name'] == country].dropna(axis=1)

    # Convert values to numeric
    country_data = country_data.apply(pd.to_numeric, errors='coerce')

    # Plotting for the current country
    plt.plot(country_data.columns[1:], country_data.iloc[:, 1:].values.squeeze(), label=country, marker='o', linestyle='-')

plt.title('GDP Growth Rate Over Time - India and United States')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')

# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)
plt.tight_layout()

# Show legend
plt.legend()
plt.show()

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland'
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Function to calculate the average GDP growth rate for a list of countries
def calculate_avg_growth_rate(countries, df):
    data = df[df['Country Name'].isin(countries)].apply(pd.to_numeric, errors='coerce')
    avg_growth_rate = data.mean(axis=0)
    return avg_growth_rate

# List of continents and their corresponding country lists
continents = {
    'Africa': africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Plotting
plt.figure(figsize=(12, 8))

for continent, countries in continents.items():
    avg_growth_rate = calculate_avg_growth_rate(countries, df)
    plt.plot(df.columns[1:].astype(int), avg_growth_rate[1:], label=continent, marker='o')  # Skip the first column

plt.title('Average GDP Growth Rate Over Time - Continents and Regions')
plt.xlabel('Year')
plt.ylabel('Average GDP Growth Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# Function to calculate the average GDP growth rate for a list of countries
def calculate_avg_growth_rate(countries, df):
    data = df[df['Country Name'].isin(countries)].apply(pd.to_numeric, errors='coerce')
    avg_growth_rate = data.mean(axis=0)
    return avg_growth_rate

# List of continents and their corresponding country lists
continents = {
    
    "Western Europe": western_europe,
    'North America': north_america_countries,
    'Asia': asia_countries,
    'Middle East': middle_east_countries,
}

# Plotting
plt.figure(figsize=(12, 8))

for continent, countries in continents.items():
    avg_growth_rate = calculate_avg_growth_rate(countries, df)
    plt.plot(df.columns[1:].astype(int), avg_growth_rate[1:], label=continent, marker='o')  # Skip the first column

plt.title('Average GDP Growth Rate Over Time for Continents and Regions')
plt.xlabel('Year')
plt.ylabel('Average GDP Growth Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# List of first-world countries
first_world_countries = ['India','United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']

# Increase figure size
plt.figure(figsize=(12, 8))

# Iterate through first-world countries and plot
for country in first_world_countries:
    # Extract the data for the current country
    country_data = df[df['Country Name'] == country].dropna(axis=1)

    # Convert values to numeric
    country_data = country_data.apply(pd.to_numeric, errors='coerce')

    # Plotting for the current country
    plt.plot(country_data.columns[1:], country_data.iloc[:, 1:].values.squeeze(), label=country, marker='o', linestyle='-')

plt.title('GDP Growth Rate Over Time - India and First World Countries')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')

# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)
plt.tight_layout()

# Show legend
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'

# List of first-world countries
first_world_countries = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']

# List of countries in the Indian subcontinent
indian_subcontinent_countries = ['India']

# Increase figure size
plt.figure(figsize=(12, 8))

# Calculate and plot the average GDP growth rate for first-world countries
avg_gdp_growth_rate_first_world = df[df['Country Name'].isin(first_world_countries)].iloc[:, 2:].apply(pd.to_numeric, errors='coerce').mean(axis=0)
plt.plot(avg_gdp_growth_rate_first_world.index, avg_gdp_growth_rate_first_world, label='Average (First World)', marker='o', linestyle='--')

# Plot GDP growth rate for India
for country in indian_subcontinent_countries:
    country_data = df[df['Country Name'] == country].dropna(axis=1)
    country_data = country_data.apply(pd.to_numeric, errors='coerce')
    plt.plot(country_data.columns[1:], country_data.iloc[:, 1:].values.squeeze(), label=f'{country} (India)', marker='o', linestyle='-')

plt.title('Average GDP Growth Rate Over Time for First World Countries and India')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')

# Format x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.xticks(df.columns[1::5])  # Assuming years are the columns
plt.grid(True)
plt.tight_layout()

# Show legend
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']

# Replace 'NA' with NaN and convert the DataFrame to numeric
df_india.replace('NA', np.nan, inplace=True)
df_india = df_india.apply(pd.to_numeric, errors='coerce')

# Extract years and GDP growth values
years_india = df_india.columns[1:].values.astype(int)
gdp_growth_india = df_india.iloc[:, 1:].values.flatten()

# Handle missing values by filling with the mean
gdp_growth_india = np.nan_to_num(gdp_growth_india, nan=np.nanmean(gdp_growth_india))

# Filter data for training on years 1961 to 2022
start_year_training = 1961
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for India
years_india_training = years_india[mask_training]
gdp_growth_india_training = gdp_growth_india[mask_training]

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_growth_india, label='Actual GDP Growth (India)', marker='o', linestyle='-')

# ARIMA order selection (You can experiment with different values)
order_india = (0, 1, 0)

# ARIMA for India with different order
model_india = ARIMA(gdp_growth_india_training, order=order_india)
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_gdp_growth_india = fit_india.forecast(steps=len(future_years_india))

# Print predicted values for India
print("Predicted GDP Growth (India):", predicted_gdp_growth_india)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)
mse_india = mean_squared_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

# Plot predicted values for India
plt.plot(future_years_india, predicted_gdp_growth_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('GDP Growth Prediction for India (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1960, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP Growth (India): [7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154]
# MAE (India): 1.832298452785714
# MSE (India): 8.869083338104165
# /var/folders/h1/6025h_3n69s9h1v7w12_f24c0000gn/T/ipykernel_10954/1430885483.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_india.replace('NA', np.nan, inplace=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India'].copy()  # Make a copy to avoid SettingWithCopyWarning

# Replace 'NA' with NaN and convert the DataFrame to numeric
df_india.replace('NA', np.nan, inplace=True)
df_india = df_india.apply(pd.to_numeric, errors='coerce')

# Extract years and GDP growth values
years_india = df_india.columns[1:].values.astype(int)
gdp_growth_india = df_india.iloc[:, 1:].values.flatten()

# Handle missing values by filling with the mean
gdp_growth_india = np.nan_to_num(gdp_growth_india, nan=np.nanmean(gdp_growth_india))

# Filter data for training on years 1961 to 2022
start_year_training = 1961
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for India
years_india_training = years_india[mask_training]
gdp_growth_india_training = gdp_growth_india[mask_training]

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_growth_india, label='Actual GDP Growth (India)', marker='o', linestyle='-')

# ARIMA order selection (You can experiment with different values)
order_india = (0, 1, 0)

# ARIMA for India with different order
model_india = ARIMA(gdp_growth_india_training, order=order_india)
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_gdp_growth_india = fit_india.forecast(steps=len(future_years_india))

# Print predicted values for India
print("Predicted GDP Growth (India):", predicted_gdp_growth_india)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)
mse_india = mean_squared_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

# Plot predicted values for India
plt.plot(future_years_india, predicted_gdp_growth_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Select data for first-world countries
first_world_countries = ['United States', 'United Kingdom', 'Germany', 'France', 'Canada', 'Italy', 'Japan', 'Australia', 'China']
df_first_world = df[df['Country Name'].isin(first_world_countries)].copy()  # Make a copy to avoid SettingWithCopyWarning

# Replace 'NA' with NaN and convert the DataFrame to numeric
df_first_world.replace('NA', np.nan, inplace=True)
df_first_world = df_first_world.apply(pd.to_numeric, errors='coerce')

# Extract years and GDP growth values
years_first_world = df_first_world.columns[1:].values.astype(int)
avg_gdp_growth_rate_first_world = df_first_world.iloc[:, 1:].mean()

# Plot actual values for first-world average
plt.plot(years_first_world, avg_gdp_growth_rate_first_world, label='Average GDP Growth (First World)', marker='o', linestyle='-')

# ARIMA for first-world average
order_first_world = (0, 1, 0)
model_first_world = ARIMA(avg_gdp_growth_rate_first_world, order=order_first_world)
fit_first_world = model_first_world.fit()
predicted_gdp_growth_first_world = fit_first_world.forecast(steps=len(future_years_india))

# Print predicted values for first-world average
print("Predicted Average GDP Growth (First World):", predicted_gdp_growth_first_world)

# Ensure that predicted_gdp_growth_first_world has the same length as years_first_world
years_first_world = years_india[-1] + np.arange(1, len(predicted_gdp_growth_first_world) + 1)

# Plot predicted values for first-world average
plt.plot(years_first_world, predicted_gdp_growth_first_world, label='ARIMA Prediction (First World)', linestyle='--', color='green')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('GDP Growth Prediction for India and First World (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1960, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP Growth (India): [7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154]
# MAE (India): 1.832298452785714
# MSE (India): 8.869083338104165
# Predicted Average GDP Growth (First World): 2023-01-01    2.80208
# 2024-01-01    2.80208
# 2025-01-01    2.80208
# 2026-01-01    2.80208
# 2027-01-01    2.80208
# 2028-01-01    2.80208
# 2029-01-01    2.80208
# 2030-01-01    2.80208
# 2031-01-01    2.80208
# 2032-01-01    2.80208
# 2033-01-01    2.80208
# 2034-01-01    2.80208
# 2035-01-01    2.80208
# 2036-01-01    2.80208
# 2037-01-01    2.80208
# 2038-01-01    2.80208
# 2039-01-01    2.80208
# 2040-01-01    2.80208
# 2041-01-01    2.80208
# 2042-01-01    2.80208
# 2043-01-01    2.80208
# 2044-01-01    2.80208
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India'].copy()  # Make a copy to avoid SettingWithCopyWarning

# Replace 'NA' with NaN and convert the DataFrame to numeric
df_india.replace('NA', np.nan, inplace=True)
df_india = df_india.apply(pd.to_numeric, errors='coerce')

# Extract years and GDP growth values
years_india = df_india.columns[1:].values.astype(int)
gdp_growth_india = df_india.iloc[:, 1:].values.flatten()

# Handle missing values by filling with the mean
gdp_growth_india = np.nan_to_num(gdp_growth_india, nan=np.nanmean(gdp_growth_india))

# Filter data for training on years 1961 to 2022
start_year_training = 1961
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for India
years_india_training = years_india[mask_training]
gdp_growth_india_training = gdp_growth_india[mask_training]

# Reshape the data for linear regression
X_india = years_india_training.reshape(-1, 1)

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_growth_india, label='Actual GDP Growth (India)', marker='o', linestyle='-')

# Linear regression model for India
model_india = LinearRegression()
model_india.fit(X_india, gdp_growth_india_training)
predicted_gdp_growth_india_training = model_india.predict(X_india)

# Print predicted values for India
print("Predicted GDP Growth (India):", predicted_gdp_growth_india_training)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_growth_india_training, predicted_gdp_growth_india_training)
mse_india = mean_squared_error(gdp_growth_india_training, predicted_gdp_growth_india_training)
r2_india = r2_score(gdp_growth_india_training, predicted_gdp_growth_india_training)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)
print("R-squared (India):", r2_india)

# Plot predicted values for India
plt.plot(years_india_training, predicted_gdp_growth_india_training, label='Linear Regression Prediction (India)', linestyle='--', color='blue')

# Predict values for the years 2023 to 2050
future_years_india = np.arange(2023, 2051).reshape(-1, 1)
predicted_gdp_growth_india_future = model_india.predict(future_years_india)

# Print predicted values for the future
print("Predicted GDP Growth (India) for 2023 to 2050:", predicted_gdp_growth_india_future)

# Plot predicted values for the future
plt.plot(future_years_india.flatten(), predicted_gdp_growth_india_future, label='Linear Regression Prediction (India, Future)', linestyle='--', color='orange')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('GDP Growth Prediction for India (Linear Regression)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1960, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP Growth (India): [3.51805812 3.57111569 3.62417327 3.67723085 3.73028843 3.783346
#  3.83640358 3.88946116 3.94251874 3.99557631 4.04863389 4.10169147
#  4.15474904 4.20780662 4.2608642  4.31392178 4.36697935 4.42003693
#  4.47309451 4.52615208 4.57920966 4.63226724 4.68532482 4.73838239
#  4.79143997 4.84449755 4.89755513 4.9506127  5.00367028 5.05672786
#  5.10978543 5.16284301 5.21590059 5.26895817 5.32201574 5.37507332
#  5.4281309  5.48118847 5.53424605 5.58730363 5.64036121 5.69341878
#  5.74647636 5.79953394 5.85259152 5.90564909 5.95870667 6.01176425
#  6.06482182 6.1178794  6.17093698 6.22399456 6.27705213 6.33010971
#  6.38316729 6.43622487 6.48928244 6.54234002 6.5953976  6.64845517
#  6.70151275 6.75457033]
# MAE (India): 2.193156308416011
# MSE (India): 9.308922058525246
# R-squared (India): 0.0882955189854332
# Predicted GDP Growth (India) for 2023 to 2050: [6.80762791 6.86068548 6.91374306 6.96680064 7.01985821 7.07291579
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score  # Import R-squared score

# Assuming your DataFrame is named df

# Select data for India
df_india = df[df['Country Name'] == 'India']

# Replace 'NA' with NaN and convert the DataFrame to numeric
df_india.replace('NA', np.nan, inplace=True)
df_india = df_india.apply(pd.to_numeric, errors='coerce')

# Extract years and GDP growth values
years_india = df_india.columns[1:].values.astype(int)
gdp_growth_india = df_india.iloc[:, 1:].values.flatten()

# Handle missing values by filling with the mean
gdp_growth_india = np.nan_to_num(gdp_growth_india, nan=np.nanmean(gdp_growth_india))

# Filter data for training on years 1961 to 2022
start_year_training = 1961
end_year_training = 2022
mask_training = (years_india >= start_year_training) & (years_india <= end_year_training)

# Apply the mask for India
years_india_training = years_india[mask_training]
gdp_growth_india_training = gdp_growth_india[mask_training]

# Set a larger plot size
plt.figure(figsize=(12, 6))

# Plot actual values for India
plt.plot(years_india, gdp_growth_india, label='Actual GDP Growth (India)', marker='o', linestyle='-')

# ARIMA order selection (You can experiment with different values)
order_india = (0, 1, 0)

# ARIMA for India with different order
model_india = ARIMA(gdp_growth_india_training, order=order_india)
fit_india = model_india.fit()
future_years_india = np.arange(2023, 2051)
predicted_gdp_growth_india = fit_india.forecast(steps=len(future_years_india))

# Print predicted values for India
print("Predicted GDP Growth (India):", predicted_gdp_growth_india)

# Calculate and print accuracy measures
mae_india = mean_absolute_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)
mse_india = mean_squared_error(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)

print("MAE (India):", mae_india)
print("MSE (India):", mse_india)

# Calculate and print R-squared value
r2_india = r2_score(gdp_growth_india[-len(future_years_india):], predicted_gdp_growth_india)
print("R-squared (India):", r2_india)

# Plot predicted values for India
plt.plot(future_years_india, predicted_gdp_growth_india, label='ARIMA Prediction (India)', linestyle='--', color='blue')

# Add labels, title, and legend
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('GDP Growth Prediction for India (ARIMA)')
plt.legend()

# Increment x-axis ticks by 5
plt.xticks(range(1960, 2051, 5), rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Predicted GDP Growth (India): [7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154 7.00295154 7.00295154
#  7.00295154 7.00295154 7.00295154 7.00295154]
# MAE (India): 1.832298452785714
# MSE (India): 8.869083338104165
# R-squared (India): -0.07811610374574718
# /var/folders/h1/6025h_3n69s9h1v7w12_f24c0000gn/T/ipykernel_10954/1152454924.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_india.replace('NA', np.nan, inplace=True)
