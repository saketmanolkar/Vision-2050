# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '/Users/saketmanolkar/Desktop/india/PopulationGrowth.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)  


# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
df
# Out:
#                     Country Name 1960      1961      1962      1963      1964  \
# 0                          Aruba   NA  2.179059  1.548572  1.389337  1.215721
# 1    Africa Eastern and Southern   NA   2.66018  2.732633  2.753248  2.806915
# 2                    Afghanistan   NA  1.925952  2.014879  2.078997  2.139651
# 3     Africa Western and Central   NA  2.115789  2.145723  2.190827   2.21136
# 4                         Angola   NA  1.558355  1.460738  1.410425  1.301745
# ..                           ...  ...       ...       ...       ...       ...
# 261                       Kosovo   NA  1.986474  2.857337  2.777956  2.702867
# 262                  Yemen, Rep.   NA  1.862737  1.872291  1.839467  1.920052
# 263                 South Africa   NA  2.799492  2.978651   3.03344  3.061378
# 264                       Zambia   NA  3.156056  3.178563  3.196632  3.194441
# 265                     Zimbabwe   NA  3.094865   3.10532  3.115408  3.119878
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Drop rows with NaN values
india_data_cleaned = india_data.dropna(axis=1)

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India
years_actual_india = india_data_cleaned.columns.astype(int)
values_actual_india = india_data_cleaned.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - India')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
india_data
# Out:
#      1960      1961      1962      1963      1964    1965      1966      1967  \
# 109   NaN  2.304706  2.311689  2.309079  2.301192  2.2353  2.151838  2.128767
#
#          1968      1969  ...      2013      2014      2015      2016  \
# 109  2.168862  2.203157  ...  1.297549  1.240362  1.187795  1.185046
#
#          2017      2018      2019      2020      2021      2022
# 109  1.155624  1.087528  1.025311  0.955221  0.797216  0.680373
#
# [1 rows x 63 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka','Bhutan']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Population growth'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - Indian Subcontinent')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'Pakistan']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Population growth'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - India and Pakistan')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'United States']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Population growth'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - India and United States')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and China
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Population growth'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - India and China')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India','United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the population growth for selected countries
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Population growth'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Over the Years - India and First World Countries')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)

# Move the legend outside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland',
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania',
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Dictionary of country groups
regions = {
    "Africa": africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Set a larger figure size
plt.figure(figsize=(12, 8))

# Loop through regions and plot Population growth
for region, countries in regions.items():
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    region_data_filled = region_data.fillna(region_data.mean())

    years = region_data_filled.columns.astype(int)
    values = region_data_filled.mean(axis=0).values  # Taking the mean for simplicity, you can customize this

    plt.plot(years, values, marker='o', label=region)

# Adding labels and title
plt.title('Population Growth Rate Over the Years - Regions and Continents')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)

# Move the legend outside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')


# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Dictionary of country groups
regions = {
    "Africa": africa_countries,
    
    'Europe': europe_countries,
    
    'Asia': asia_countries,
    
    'Middle East': middle_east_countries,
  
    'North America': north_america_countries,
   
    
}

# Set a larger figure size
plt.figure(figsize=(12, 8))

# Loop through regions and plot Population growth
for region, countries in regions.items():
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    region_data_filled = region_data.fillna(region_data.mean())

    years = region_data_filled.columns.astype(int)
    values = region_data_filled.mean(axis=0).values  # Taking the mean for simplicity, you can customize this

    plt.plot(years, values, marker='o', label=region)

# Adding labels and title
plt.title('Population growth Across Different Regions Over the Years')
plt.xlabel('Year')
plt.ylabel('Population growth')
plt.grid(True)

# Move the legend outside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')


# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for selected countries
countries_of_interest = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Group by year and calculate the average population growth
average_population_growth = selected_data.groupby('Year')['Population growth'].mean().reset_index()

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the average population growth
plt.plot(average_population_growth['Year'], average_population_growth['Population growth'], marker='o', label='Average Population Growth')

# Adding labels and title
plt.title('Average Population Growth for Average of First World Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Population Growth')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the population growth for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title for India
plt.title('Population growth in India Over the Years')
plt.xlabel('Year')
plt.ylabel('Population growth')
plt.grid(True)

# Filter data for selected countries
countries_of_interest = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Group by year and calculate the average population growth
average_population_growth = selected_data.groupby('Year')['Population growth'].mean().reset_index()

# Plotting the average population growth for selected countries
plt.plot(average_population_growth['Year'], average_population_growth['Population growth'], marker='o', label='Average Population Growth (First World Countires)')

# Adding labels and title for average population growth
plt.title('Population growth in India vs Average of First World Countires Over the Years')
plt.xlabel('Year')
plt.ylabel('Population growth')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the population growth for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Population Growth Rate Prediction in India and Average of First World Over the Years')
plt.xlabel('Year')
plt.ylabel('Population growth (annual %)')
plt.grid(True)

# Average population growth for selected countries
countries_of_interest = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Population growth')
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')
average_population_growth = selected_data.groupby('Year')['Population growth'].mean().reset_index()

# Plotting the actual values for the average of first-world countries
plt.plot(average_population_growth['Year'], average_population_growth['Population growth'], marker='o', label='Average of First World (Actual)')

# ARIMA for India
order_arima_india = (2, 0, 0)  # You may need to adjust the order based on the characteristics of your data
model_arima_india = ARIMA(values_actual_india, order=order_arima_india)
fitted_model_arima_india = model_arima_india.fit()  # Use the default 'lbfgs' method
arima_predictions_india = fitted_model_arima_india.predict(start=values_actual_india.shape[0], end=values_actual_india.shape[0] + 27)  # Predict from 2023 to 2050

# Plotting the ARIMA predicted values for India
plt.plot(np.arange(2023, 2051), arima_predictions_india, label='ARIMA (Predicted - India)', linestyle='--')

# ARIMA for the average of first-world countries
values_average_first_world = average_population_growth['Population growth']
order_arima_average_first_world = (1, 0, 1)  # You may need to adjust the order based on the characteristics of your data
model_arima_average_first_world = ARIMA(values_average_first_world, order=order_arima_average_first_world)
fitted_model_arima_average_first_world = model_arima_average_first_world.fit()  # Use the default 'lbfgs' method
arima_predictions_average_first_world = fitted_model_arima_average_first_world.predict(start=values_average_first_world.shape[0], end=values_average_first_world.shape[0] + 27)  # Predict from 2023 to 2050

# Plotting the ARIMA predicted values for the average of first-world countries
plt.plot(np.arange(2023, 2051), arima_predictions_average_first_world, label='ARIMA (Predicted - Average of First World)', linestyle='--')

# Calculate and print metrics for ARIMA - India
r2_arima_india = r2_score(values_actual_india[-len(arima_predictions_india):], arima_predictions_india)
mse_arima_india = mean_squared_error(values_actual_india[-len(arima_predictions_india):], arima_predictions_india)
mae_arima_india = mean_absolute_error(values_actual_india[-len(arima_predictions_india):], arima_predictions_india)
print(f"Metrics for ARIMA - India:")
print(f"R-squared: {r2_arima_india}")
print(f"Mean Squared Error (MSE): {mse_arima_india}")
print(f"Mean Absolute Error (MAE): {mae_arima_india}")

# Calculate and print metrics for ARIMA - Average of First World
r2_arima_average_first_world = r2_score(values_average_first_world[-len(arima_predictions_average_first_world):], arima_predictions_average_first_world)
mse_arima_average_first_world = mean_squared_error(values_average_first_world[-len(arima_predictions_average_first_world):], arima_predictions_average_first_world)
mae_arima_average_first_world = mean_absolute_error(values_average_first_world[-len(arima_predictions_average_first_world):], arima_predictions_average_first_world)
print(f"Metrics for ARIMA - Average of First World:")
print(f"R-squared: {r2_arima_average_first_world}")
print(f"Mean Squared Error (MSE): {mse_arima_average_first_world}")
print(f"Mean Absolute Error (MAE): {mae_arima_average_first_world}")

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Metrics for ARIMA - India:
# R-squared: -11.44353079647397
# Mean Squared Error (MSE): 1.574534860876852
# Mean Absolute Error (MAE): 1.214589107768809
# Metrics for ARIMA - Average of First World:
# R-squared: -0.9913210724083799
# Mean Squared Error (MSE): 0.03238551619189284
# Mean Absolute Error (MAE): 0.11619269585730538

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Population growth in India Over the Years')
plt.xlabel('Year')
plt.ylabel('Population growth')
plt.grid(True)

# ARIMA
order_arima = (2, 0, 0)  # You may need to adjust the order based on the characteristics of your data
model_arima = ARIMA(values_actual_india, order=order_arima)
fitted_model_arima = model_arima.fit()  # Use the default 'lbfgs' method
arima_predictions = fitted_model_arima.predict(start=len(values_actual_india), end=len(values_actual_india) + 27)  # Predict from 2023 to 2050

# Print predicted values for ARIMA
print("Predicted Values for the Years 2023 to 2050 (ARIMA):")
for year, prediction in zip(np.arange(2023, 2051), arima_predictions):
    print(f"Year {year}: {prediction}")

plt.plot(np.arange(2023, 2051), arima_predictions, label='ARIMA (Predicted)', linestyle='--')

# Drop NaN values for calculation
values_actual_india_no_nan = values_actual_india[~np.isnan(values_actual_india)]
fittedvalues_arima_no_nan = fitted_model_arima.fittedvalues[~np.isnan(fitted_model_arima.fittedvalues)]

# Align lengths of the two arrays
min_length = min(len(values_actual_india_no_nan), len(fittedvalues_arima_no_nan))
values_actual_india_no_nan = values_actual_india_no_nan[:min_length]
fittedvalues_arima_no_nan = fittedvalues_arima_no_nan[:min_length]

# Calculate and print R-squared for ARIMA
r2_arima = r2_score(values_actual_india_no_nan, fittedvalues_arima_no_nan)
print(f"R-squared for ARIMA: {r2_arima}")

# Calculate and print MSE for ARIMA
mse_arima = mean_squared_error(values_actual_india_no_nan, fittedvalues_arima_no_nan)
print(f"Mean Squared Error (MSE) for ARIMA: {mse_arima}")

# Calculate and print MAE for ARIMA
mae_arima = mean_absolute_error(values_actual_india_no_nan, fittedvalues_arima_no_nan)
print(f"Mean Absolute Error (MAE) for ARIMA: {mae_arima}")

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Predicted Values for the Years 2023 to 2050 (ARIMA):
# Year 2023: 0.5806310096834211
# Year 2024: 0.4958350382220702
# Year 2025: 0.4240957518884829
# Year 2026: 0.36375856317975297
# Year 2027: 0.31337420831330975
# Year 2028: 0.2716733325156022
# Year 2029: 0.23754422013084797
# Year 2030: 0.21001328042427825
# Year 2031: 0.1882279481026874
# Year 2032: 0.171441699765851
# Year 2033: 0.15900092447266867
# Year 2034: 0.15033341900166897
# Year 2035: 0.14493830677281028
# Year 2036: 0.14237720427231593
# Year 2037: 0.142266480619208
# Year 2038: 0.14427047501208867
# Year 2039: 0.14809555353128645
# Year 2040: 0.15348490143716176
# Year 2041: 0.16021395995637966
# Year 2042: 0.16808642780886118
# Year 2043: 0.17693075759566068
# Year 2044: 0.18659708581459733
# Year 2045: 0.19695454284716085
# Year 2046: 0.20788889589941095
# Year 2047: 0.2193004836972834
# Year 2048: 0.23110240683456085
# Year 2049: 0.24321894213883155
# Year 2050: 0.2555841533350882
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Population growth (annual %) - India - Linear Regression vs ARIMA')
plt.xlabel('Year')
plt.ylabel('Population growth')
plt.grid(True)

# Linear Regression
years_linear_regression = np.array(years_actual_india).reshape(-1, 1)
values_actual_india_no_nan = values_actual_india[~np.isnan(values_actual_india)]  # Remove NaN values for fitting
years_linear_regression_no_nan = years_linear_regression[~np.isnan(values_actual_india)]
model_linear = LinearRegression()
model_linear.fit(years_linear_regression_no_nan, values_actual_india_no_nan)

# Predicting for the actual years
linear_regression_predictions_actual = model_linear.predict(years_linear_regression_no_nan.reshape(-1, 1))

# Plotting Linear Regression predictions for the actual years
plt.plot(years_linear_regression_no_nan, linear_regression_predictions_actual, label='Linear Regression (Actual)', linestyle='--')

# Predicting for the future years (2023 to 2050)
years_future = np.arange(2023, 2051).reshape(-1, 1)
linear_regression_predictions_future = model_linear.predict(years_future)
plt.plot(np.arange(2023, 2051), linear_regression_predictions_future, label='Linear Regression (Predicted)', linestyle='--')

# Calculate and print R-squared for Linear Regression
r2_linear = model_linear.score(years_linear_regression_no_nan, values_actual_india_no_nan)
print(f"R-squared for Linear Regression: {r2_linear}")

# ARIMA
order_arima = (2, 0, 0)  # You may need to adjust the order based on the characteristics of your data
model_arima = ARIMA(values_actual_india, order=order_arima)
fitted_model_arima = model_arima.fit()  # Use the default 'lbfgs' method
arima_predictions = fitted_model_arima.predict(start=len(values_actual_india), end=len(values_actual_india) + 27)  # Predict from 2023 to 2050
plt.plot(np.arange(2023, 2051), arima_predictions, label='ARIMA (Predicted)', linestyle='--')

# Calculate and print R-squared for ARIMA
residuals_arima = values_actual_india - fitted_model_arima.fittedvalues
ssr_arima = np.sum(residuals_arima**2)
sst_arima = np.sum((values_actual_india - np.mean(values_actual_india))**2)
r2_arima = 1 - (ssr_arima / sst_arima)
print(f"R-squared for ARIMA: {r2_arima}")

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# R-squared for Linear Regression: 0.8290520296906739
# R-squared for ARIMA: nan
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
