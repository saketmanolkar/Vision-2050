# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '/Users/saketmanolkar/Desktop/india/Literacy rate.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)  


# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
df
# Out:
#                     Country Name 1960 1961 1962 1963 1964 1965 1966 1967 1968  \
# 0                          Aruba   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 1    Africa Eastern and Southern   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 2                    Afghanistan   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 3     Africa Western and Central   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 4                         Angola   NA   NA   NA   NA   NA   NA   NA   NA   NA
# ..                           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 261                       Kosovo   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 262                  Yemen, Rep.   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 263                 South Africa   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 264                       Zambia   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 265                     Zimbabwe   NA   NA   NA   NA   NA   NA   NA   NA   NA
#
#      ...       2013       2014       2015      2016       2017       2018  \
# 0    ...         NA         NA         NA        NA         NA         NA
# 1    ...  69.383102   69.83477  70.313423   71.0952  71.009071  71.392616
# 2    ...         NA         NA         NA        NA         NA         NA
# 3    ...  53.002781   54.00676  54.818321  55.43792  56.485538  59.568459
# 4    ...         NA  66.030113         NA        NA         NA         NA
# ..   ...        ...        ...        ...       ...        ...        ...
# 261  ...         NA         NA         NA        NA         NA         NA
# 262  ...         NA         NA         NA        NA         NA         NA
# 263  ...         NA    94.1399   94.36792        NA  87.046669         NA
# 264  ...         NA         NA         NA        NA         NA         NA
# 265  ...         NA   88.69342         NA        NA         NA         NA
#
#           2019       2020       2021       2022
# 0           NA  97.989998         NA         NA
# 1    72.634972  72.785622  72.581161  72.600403
# 2           NA         NA  37.266041         NA
# 3    59.511719  59.617512  60.034611  60.312698
# 4           NA         NA         NA  72.400002
# ..         ...        ...        ...        ...
# 261         NA         NA         NA         NA
# 262         NA         NA         NA         NA
# 263  95.022972         NA  90.001358         NA
# 264         NA       87.5         NA         NA
# 265         NA         NA         NA  89.849998
#
# [266 rows x 64 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Drop rows with NaN values
india_data_cleaned = india_data.dropna(axis=1)

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India
years_actual_india = india_data_cleaned.columns.astype(int)
values_actual_india = india_data_cleaned.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Literacy Rate Over the Years - India')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Literacy Rate')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Literacy Rate'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Literacy Rate Over the Years - Indian Subcontinent')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['India', 'China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Literacy Rate')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Literacy Rate'], marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Literacy Rate Over the Years - India and China')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India and Pakistan
countries_of_interest = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia','China']
selected_data = df[df['Country Name'].isin(countries_of_interest)]

# Transpose the DataFrame to have years as rows and countries as columns
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Literacy Rate')

# Convert 'Year' column to numeric
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India and Pakistan with connected lines
for country in countries_of_interest:
    data_country = selected_data[selected_data['Country Name'] == country]
    plt.plot(data_country['Year'], data_country['Literacy Rate'], marker='o', label=f'{country} (Actual)', linestyle='-')

# Adding labels and title
plt.title('Literacy Rate in First World Countries Over the Years')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
print(selected_data)
# Out:
#        Country Name  Year  Literacy Rate
# 0         Australia  1960            NaN
# 1            Canada  1960            NaN
# 2             China  1960            NaN
# 3           Germany  1960            NaN
# 4            France  1960            NaN
# ..              ...   ...            ...
# 499         Germany  2022            NaN
# 500          France  2022            NaN
# 501  United Kingdom  2022            NaN
# 502           Japan  2022            NaN
# 503   United States  2022            NaN
#
# [504 rows x 3 columns]

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland',
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania',
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Dictionary of country groups
regions = {
    "Africa": africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Set a larger figure size
plt.figure(figsize=(12, 8))

# Loop through regions and plot literacy rates
for region, countries in regions.items():
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    region_data_filled = region_data.fillna(region_data.mean())

    years = region_data_filled.columns.astype(int)
    values = region_data_filled.mean(axis=0).values  # Taking the mean for simplicity, you can customize this

    plt.plot(years, values, marker='o', label=region)

# Adding labels and title
plt.title('Literacy Rates Across Different Regions Over the Years')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)

# Show the legend
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Dictionary of country groups
regions = {
    
    
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
}

# Set a larger figure size
plt.figure(figsize=(12, 8))

# Loop through regions and plot literacy rates
for region, countries in regions.items():
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    region_data_filled = region_data.fillna(region_data.mean())

    years = region_data_filled.columns.astype(int)
    values = region_data_filled.mean(axis=0).values  # Taking the mean for simplicity, you can customize this

    plt.plot(years, values, marker='o', label=region)

# Adding labels and title
plt.title('Literacy Rates Across Different Regions Over the Years')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Literacy Rate in India Over the Years')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)

# Linear Regression
years_linear_regression = np.array(years_actual_india).reshape(-1, 1)
values_actual_india_no_nan = values_actual_india[~np.isnan(values_actual_india)]  # Remove NaN values for fitting
years_linear_regression_no_nan = years_linear_regression[~np.isnan(values_actual_india)]
model_linear = LinearRegression()
model_linear.fit(years_linear_regression_no_nan, values_actual_india_no_nan)
linear_regression_predictions = model_linear.predict(years_linear_regression)

# Plotting Linear Regression predictions from 2023 to 2050
years_future = np.arange(2023, 2051).reshape(-1, 1)
linear_regression_predictions_future = model_linear.predict(years_future)
plt.plot(np.arange(2023, 2051), linear_regression_predictions_future, label='Linear Regression (Predicted)', linestyle='--')

# Calculate and print R-squared for Linear Regression
r2_linear = model_linear.score(years_linear_regression_no_nan, values_actual_india_no_nan)
print(f"R-squared for Linear Regression: {r2_linear}")

# ARIMA
order_arima = (1, 1, 1)  # You may need to adjust the order based on the characteristics of your data
model_arima = ARIMA(values_actual_india, order=order_arima)
fitted_model_arima = model_arima.fit()  # Use the default 'lbfgs' method
arima_predictions = fitted_model_arima.predict(start=len(values_actual_india), end=len(values_actual_india) + 27)  # Predict from 2023 to 2050
plt.plot(np.arange(2023, 2051), arima_predictions, label='ARIMA (Predicted)', linestyle='--')

# Calculate and print R-squared for ARIMA
residuals_arima = values_actual_india - fitted_model_arima.fittedvalues
ssr_arima = np.sum(residuals_arima**2)
sst_arima = np.sum((values_actual_india - np.mean(values_actual_india))**2)
r2_arima = 1 - (ssr_arima / sst_arima)
print(f"R-squared for ARIMA: {r2_arima}")

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# R-squared for Linear Regression: 0.9863870596483736
# R-squared for ARIMA: nan
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/saketmanolkar/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Fill missing values using the mean
india_data_filled = india_data.fillna(india_data.mean())

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India (Actual)
years_actual_india = india_data_filled.columns.astype(int)
values_actual_india = india_data_filled.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Literacy Rate in India Over the Years')
plt.xlabel('Year')
plt.ylabel('Literacy Rate')
plt.grid(True)

# Linear Regression
years_linear_regression = np.array(years_actual_india).reshape(-1, 1)
values_actual_india_no_nan = values_actual_india[~np.isnan(values_actual_india)]  # Remove NaN values for fitting
years_linear_regression_no_nan = years_linear_regression[~np.isnan(values_actual_india)]
model_linear = LinearRegression()
model_linear.fit(years_linear_regression_no_nan, values_actual_india_no_nan)
linear_regression_predictions = model_linear.predict(years_linear_regression)

# Polynomial Regression with Degree 2
poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(years_linear_regression_no_nan)
model_poly = LinearRegression()
model_poly.fit(X_poly, values_actual_india_no_nan)
poly_predictions = model_poly.predict(poly_features.transform(years_linear_regression_no_nan))

# Print R-squared for Polynomial Regression (Degree 2)
r2_poly = r2_score(values_actual_india_no_nan, poly_predictions)
print(f"R-squared for Polynomial Regression (Degree 2): {r2_poly}")

# Print the predicted values
poly_predictions_future = model_poly.predict(poly_features.transform(np.arange(2023, 2051).reshape(-1, 1)))
print("Predicted Values for the Years 2023 to 2050 (Polynomial Regression Degree 2):")
for year, prediction in zip(np.arange(2023, 2051), poly_predictions_future):
    print(f"Year {year}: {prediction}")

# Plotting Polynomial Regression predictions from 2023 to 2050
plt.plot(np.arange(2023, 2051), poly_predictions_future, label='Polynomial Regression (Degree 2) Predicted', linestyle='--')

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# R-squared for Polynomial Regression (Degree 2): 0.9892087115557153
# Predicted Values for the Years 2023 to 2050 (Polynomial Regression Degree 2):
# Year 2023: 77.53321648696146
# Year 2024: 78.27039361354218
# Year 2025: 79.00029780004115
# Year 2026: 79.7229290464602
# Year 2027: 80.43828735280294
# Year 2028: 81.14637271906395
# Year 2029: 81.84718514524138
# Year 2030: 82.54072463134798
# Year 2031: 83.22699117736556
# Year 2032: 83.90598478330503
# Year 2033: 84.57770544917003
# Year 2034: 85.24215317494964
# Year 2035: 85.89932796065114
# Year 2036: 86.54922980627816
# Year 2037: 87.1918587118198
# Year 2038: 87.82721467728334
# Year 2039: 88.45529770266876
# Year 2040: 89.07610778797243
# Year 2041: 89.689644933198
# Year 2042: 90.29590913834181
# Year 2043: 90.89490040340752
# Year 2044: 91.48661872839148
# Year 2045: 92.07106411329733
# Year 2046: 92.64823655812143
# Year 2047: 93.21813606287105
# Year 2048: 93.7807626275353
# Year 2049: 94.33611625212143
# Year 2050: 94.88419693662945

# %%
india_data
# Out:
#      1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  2013  \
# 109   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#      2014  2015  2016  2017  2018  2019  2020  2021       2022
# 109   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  76.322777
#
# [1 rows x 63 columns]
