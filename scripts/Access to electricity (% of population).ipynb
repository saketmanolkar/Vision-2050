# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '/Users/saketmanolkar/Desktop/india/Access to electricity.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)  


# Assuming you want to fill empty fields with 'NA'
df.fillna('NA', inplace=True)

# %%
df
# Out:
#                     Country Name   1990       1991       1992       1993  \
# 0                          Aruba  100.0  99.153656  99.197128  99.239914
# 1    Africa Eastern and Southern     NA         NA         NA         NA
# 2                    Afghanistan     NA         NA         NA         NA
# 3     Africa Western and Central     NA         NA         NA   31.57513
# 4                         Angola     NA         NA         NA         NA
# ..                           ...    ...        ...        ...        ...
# 261                       Kosovo  100.0      100.0      100.0      100.0
# 262                  Yemen, Rep.     NA         NA       44.1  40.774715
# 263                 South Africa     NA         NA         NA         NA
# 264                       Zambia   13.9  12.752703       19.2  14.213207
# 265                     Zimbabwe     NA         NA       28.2  31.163668
#
#           1994       1995       1996       1997       1998  ... Unnamed: 54  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)

# Drop rows with NaN values
india_data_cleaned = india_data.dropna(axis=1)

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the literacy rate for India
years_actual_india = india_data_cleaned.columns.astype(int)
values_actual_india = india_data_cleaned.values.flatten()
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Access to electricity Over the Years - India ')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# List of countries of interest
countries_of_interest = ['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan']

# Set a larger figure size
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    # Filter data for the current country
    country_data = df[df['Country Name'] == country].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    country_data_cleaned = country_data.dropna(axis=1)

    # Plotting the access to electricity for the current country
    years_actual = country_data_cleaned.columns.astype(int)
    values_actual = country_data_cleaned.values.flatten()
    plt.plot(years_actual, values_actual, marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Access to electricity Over the Years - Indian Subcontinent')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# List of countries of interest
countries_of_interest = ['India', 'Pakistan']

# Set a larger figure size
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    # Filter data for the current country
    country_data = df[df['Country Name'] == country].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    country_data_cleaned = country_data.dropna(axis=1)

    # Plotting the access to electricity for the current country
    years_actual = country_data_cleaned.columns.astype(int)
    values_actual = country_data_cleaned.values.flatten()
    plt.plot(years_actual, values_actual, marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Access to electricity Over the Years - India and Pakistan')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# List of countries of interest
countries_of_interest = ['India', 'China']

# Set a larger figure size
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    # Filter data for the current country
    country_data = df[df['Country Name'] == country].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    country_data_cleaned = country_data.dropna(axis=1)

    # Plotting the access to electricity for the current country
    years_actual = country_data_cleaned.columns.astype(int)
    values_actual = country_data_cleaned.values.flatten()
    plt.plot(years_actual, values_actual, marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Access to electricity Over the Years - India and China')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# List of countries of interest
countries_of_interest = ['India', 'United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']

# Set a larger figure size
plt.figure(figsize=(12, 6))

for country in countries_of_interest:
    # Filter data for the current country
    country_data = df[df['Country Name'] == country].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    country_data_cleaned = country_data.dropna(axis=1)

    # Plotting the access to electricity for the current country
    years_actual = country_data_cleaned.columns.astype(int)
    values_actual = country_data_cleaned.values.flatten()
    plt.plot(years_actual, values_actual, marker='o', label=f'{country} (Actual)')

# Adding labels and title
plt.title('Access to electricity Over the Years - India and United States')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
country_data
# Out:
#     1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  ...  \
# 32   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 32          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63
# 32          NaN          NaN          NaN          NaN          NaN
#
# [1 rows x 63 columns]

# %%
# Western Europe
western_europe = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden'
]

# Southern Europe
southern_europe = [
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain'
]

# Northern Europe
northern_europe = [
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania', 'Greenland'
]

# Eastern Europe
eastern_europe = [
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania'
]

# Europe
europe_countries = [
    'Austria', 'Belgium', 'France', 'Germany',
    'Netherlands', 'Switzerland', 'United Kingdom', 'Sweden',
    'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania','Greenland',
    'Andorra', 'Gibraltar', 'Italy', 'Malta', 'Portugal', 'San Marino', 'Spain',
    'Belarus', 'Czechia', 'Hungary', 'Poland', 'Slovenia', 'Moldova', 'Ukraine', 'Romania',
]

# Africa
africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia',
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger',
     'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan',
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
    
]

#Noth Afircan Countires
northern_africa_countries = [
    'Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia'
] 

#South african Countries
southern_africa_countries = [
    'South Africa', 'Namibia', 'Botswana', 'Zimbabwe', 'Mozambique', 'Zambia'
]

# West African Countries
west_africa_countries = [
    'Nigeria', 'Ghana', 'Senegal', 'Ivory Coast', 'Mali', 'Niger'
]

# Eastern African Countires
eastern_africa_countries = [
    'Kenya', 'Ethiopia', 'Tanzania', 'Uganda', 'Rwanda', 'Sudan'
]

# Central African Countries
central_africa_countries = [
    'Congo', 'Cameroon', 'Gabon', 'Chad', 'Central African Republic', 'Equatorial Guinea'
]


# Asia
asia_countries = [
    'China', 'India', 'Indonesia', 'Japan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan',
    'Malaysia', 'Pakistan', 'Philippines', 'Singapore', 'Thailand', 'Maldives'
]

#Indian Sub continent
indian_subcontinent_countries = [
    'India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Bhutan'
]

# North America
north_america_countries = [
    'Canada', 'United States'
]

#Middle East
middle_east_countries = [
     'Bahrain', 'Cyprus', 'Iraq', 'Israel', 'Jordan', 
    'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia'
    , 'United Arab Emirates', 'Jordan'
]

# South America
south_america_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 
    'Ecuador', 'Paraguay', 'Peru', 'Suriname'
]

#Central America
central_america_countries = [
    'Mexico', 'Cuba', 'Guatemala',
    'Honduras', 'Nicaragua', 'Costa Rica', 'Panama', 'Dominican Republic'
]

# Oceania
oceania_countries = [
    'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 
    'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa'
]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Define regions and their countries
regions = {
    "Africa": africa_countries,
    "Northern Africa": northern_africa_countries,
    "Western Africa": west_africa_countries,
    "Eastern Africa": eastern_africa_countries,
    "Central Africa": central_africa_countries,
    "Southern Africa": southern_africa_countries,
    'Europe': europe_countries,
    "Northern Europe": northern_europe,
    "Western Europe": western_europe,
    "Eastern Europe": eastern_europe,
    "Southern Europe": southern_europe,
    'Asia': asia_countries,
    'Indian Subcontinent': indian_subcontinent_countries,
    'Middle East': middle_east_countries,
    'Central America': central_america_countries,
    'North America': north_america_countries,
    'South America': south_america_countries,
    'Oceania': oceania_countries
}

# Set a larger figure size
plt.figure(figsize=(12, 6))

for region, countries in regions.items():
    # Filter data for countries in the current region
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    region_data_cleaned = region_data.dropna(axis=1)

    # Plotting the access to electricity for the current region
    years_actual = region_data_cleaned.columns.astype(int)
    values_actual = region_data_cleaned.mean(axis=0)  # Use the mean value for each year
    plt.plot(years_actual, values_actual, marker='o', label=f'{region}')

# Adding labels and title
plt.title('Access to electricity Across Regions Over the Years')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)

# Place legend outside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Define regions and their countries
regions = {
    
    "Central Africa": central_africa_countries,
    'Central America': central_america_countries,
}

# Set a larger figure size
plt.figure(figsize=(12, 6))

for region, countries in regions.items():
    # Filter data for countries in the current region
    region_data = df[df['Country Name'].isin(countries)].iloc[:, 1:].astype(float)
    
    # Drop rows with NaN values
    region_data_cleaned = region_data.dropna(axis=1)

    # Plotting the access to electricity for the current region
    years_actual = region_data_cleaned.columns.astype(int)
    values_actual = region_data_cleaned.mean(axis=0)  # Use the mean value for each year
    plt.plot(years_actual, values_actual, marker='o', label=f'{region}')

# Adding labels and title
plt.title('Access to electricity Across Regions Over the Years')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)

# Place legend outside the graph
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with relevant data
# Replace 'NA' with NaN
df.replace('NA', np.nan, inplace=True)

# Selected countries
countries_of_interest = ['United States', 'Canada', 'United Kingdom', 'Germany', 'France', 'Japan', 'Australia', 'China']

# Filter data for selected countries
selected_data = df[df['Country Name'].isin(countries_of_interest)]
selected_data = selected_data.melt(id_vars='Country Name', var_name='Year', value_name='Access to electricity')
selected_data['Year'] = pd.to_numeric(selected_data['Year'], errors='coerce')

# Calculate the average for selected countries
average_selected_countries = selected_data.groupby('Year')['Access to electricity'].mean().reset_index()

# Filter data for India
india_data = df[df['Country Name'] == 'India'].iloc[:, 1:].astype(float)
india_data_cleaned = india_data.dropna(axis=1)

# Set a larger figure size
plt.figure(figsize=(12, 6))

# Plotting the average of selected countries
plt.plot(average_selected_countries['Year'], average_selected_countries['Access to electricity'], marker='o', label='Average of First World Countries')

# Plotting the access to electricity for India
years_actual_india = india_data_cleaned.columns.astype(int)
values_actual_india = india_data_cleaned.mean(axis=0)
plt.plot(years_actual_india, values_actual_india, marker='o', label='India (Actual)')

# Adding labels and title
plt.title('Access to electricity: First World Countries vs India Over the Years')
plt.xlabel('Year')
plt.ylabel('Access to electricity (% of population)')
plt.grid(True)

# Show the legend
plt.legend()

# Show the plot
plt.show()
